# %%
using PyPlot

# %% [markdown]
# Objective function is
# $$ f(x) = \frac{1}{2} x^2 $$
# so the gradient is
# $$ f(x) = x $$

# %%
function grad_f(x)
    return x
end
# Out:
# grad_f (generic function with 1 method)

# %% [markdown]
# Suppose that our samples are of the form
# $$\tilde f(x) = \frac{1}{2} (x + z)^2$$
# where $z \sim N(0,1)$ is a standard Gaussian random variable. Then
# $$ \nabla \tilde f(x) = x + z $$

# %%
function sample_grad_f(x)
    return x + randn(length(x)) / sqrt(length(x))
end
# Out:
# sample_grad_f (generic function with 1 method)

# %%
function gradient_descent(x0, alpha, num_iters)
    dist_to_optimum = zeros(num_iters)
    x = x0
    for t = 1:num_iters
        x = x - alpha * grad_f(x)
        dist_to_optimum[t] = norm(x)
    end
    return dist_to_optimum
end

function stochastic_gradient_descent(x0, alpha, num_iters)
    dist_to_optimum = zeros(num_iters)
    x = x0
    for t = 1:num_iters
        x = x - alpha * sample_grad_f(x)
        dist_to_optimum[t] = norm(x)
    end
    return dist_to_optimum
end
# Out:
# stochastic_gradient_descent (generic function with 1 method)

# %%
x0 = 5;
alpha = 0.001;
num_iters = 1000;
gd_dist = gradient_descent(x0, alpha, num_iters);
sgd_dist = stochastic_gradient_descent(x0, alpha, num_iters);

# %%
plot(1:num_iters, gd_dist, 1:num_iters, sgd_dist)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x319c83e10>)
# 2-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x319dc79d0>
#  PyObject <matplotlib.lines.Line2D object at 0x319dc7b90>

# %%
semilogy(1:num_iters, gd_dist, 1:num_iters, sgd_dist)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x319f7a250>)
# 2-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x319fb1750>
#  PyObject <matplotlib.lines.Line2D object at 0x31a118cd0>

# %%
x0 = 2 * randn(100);
alpha = 0.1;
num_iters = 5000;
gd_dist = gradient_descent(x0, alpha, num_iters);
sgd_dist = stochastic_gradient_descent(x0, alpha, num_iters);

# %%
plot(1:num_iters, gd_dist, 1:num_iters, sgd_dist)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x319f84a50>)
# 2-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31a3ccd10>
#  PyObject <matplotlib.lines.Line2D object at 0x31a3cced0>

# %%
semilogy(1:num_iters, gd_dist, 1:num_iters, sgd_dist)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31a615fd0>)
# 2-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x31a6c59d0>
#  PyObject <matplotlib.lines.Line2D object at 0x31a89c510>
